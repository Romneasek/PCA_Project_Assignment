# %% [markdown]
# <a href="https://colab.research.google.com/github/Romneasek/PCA_Project_Assignment/blob/main/PCA_Project_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(style='white', color_codes=True)

# %%
data = pd.read_csv('/content/train.csv')

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data.shape
# Out:
# (1460, 81)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# Extracting dataframe for only 'number' datatypes
df = data.select_dtypes(include=['float64','int64'])
df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# 2          2002       162.0         486  ...           0           42
# 3          1970         0.0         216  ...           0           35
# 4          2000       350.0         655  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
# getting discriptive statistcs on "number" datatypes
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
#Identifing missing Values
miss_val = df.isna().sum()
miss_val
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64

# %%
# Identifing missing Values > 0 and sorting them by ascending order
miss_val[miss_val>0].sort_values(ascending = False)
# Out:
# LotFrontage    259
# GarageYrBlt     81
# MasVnrArea       8
# dtype: int64

# %%
columns = ['LotFrontage','GarageYrBlt','MasVnrArea']
for column in columns:
    df[column] = df[column].fillna(df[column].mean())

# %%
df.isna().sum()
# Out:
# Id               0
# MSSubClass       0
# LotFrontage      0
# LotArea          0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# MasVnrArea       0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageYrBlt      0
# GarageCars       0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# SalePrice        0
# dtype: int64

# %%
df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# 2          2002       162.0         486  ...           0           42
# 3          1970         0.0         216  ...           0           35
# 4          2000       350.0         655  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
#Constructing correlation Matrix
data_corr = df.corr()
data_corr
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.009601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.357056 -0.139781     0.032628
# LotFrontage   -0.009601   -0.357056     1.000000  0.306795     0.234196
# LotArea       -0.033226   -0.139781     0.306795  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.234196  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.052820 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.117598  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.082746  0.013788     0.550684
# MasVnrArea    -0.050199    0.022895     0.179283  0.103960     0.410238
# BsmtFinSF1    -0.005024   -0.069836     0.215828  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.043340  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.122156 -0.002618     0.308159
# ...

# %%
#considering only the features which have absolute correlation value greater tha 0.60

data_corr = data_corr['SalePrice'][:-1]
data_corr[abs(data_corr)>=0.60].sort_values(ascending=False)
# Out:
# OverallQual    0.790982
# GrLivArea      0.708624
# GarageCars     0.640409
# GarageArea     0.623431
# TotalBsmtSF    0.613581
# 1stFlrSF       0.605852
# Name: SalePrice, dtype: float64

# %%
new_df = df[['OverallQual','GrLivArea','GarageCars','GarageArea','TotalBsmtSF','1stFlrSF','SalePrice']]

# %%
corr = new_df.corr()
plt.figure(figsize=(5,5))
sns.heatmap(corr, annot=True, cmap='cubehelix_r',square=True) 
plt.show()

# %%
x = new_df.drop(['SalePrice'], axis = 1)  
y = new_df['SalePrice']

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(new_df, test_size=0.25)

# %%
train_x = train.drop(['SalePrice'], axis =1)
train_y = train['SalePrice']

test_x = test.drop(['SalePrice'], axis =1)
test_y = test['SalePrice']

# %%
print('Dimension of train_x dataframe:',train_x.shape)
print('Dimension of train_y dataframe:',train_y.shape)
print('Dimension of val_x dataframe:',test_x.shape)
print('Dimension of val_y dataframe:',test_y.shape)
# Out:
# Dimension of train_x dataframe: (1095, 6)
# Dimension of train_y dataframe: (1095,)
# Dimension of val_x dataframe: (365, 6)
# Dimension of val_y dataframe: (365,)

# %%
sns.displot(y)
plt.show()

# %%
y.skew()
# Out:
# 1.8828757597682129

# %%
from scipy import stats
y=stats.boxcox(y)[0]

# %%
sns.distplot(y)
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

min_max_scaler = MinMaxScaler()

min_max_scaler.fit(new_df)
# Out:
# MinMaxScaler()

# %%
# get scaled data 
dataset_scaled = pd.DataFrame(min_max_scaler.transform(new_df))

# assign column labels
dataset_scaled.columns = new_df.columns

# %%
dataset_scaled.describe()
# Out:
#        OverallQual    GrLivArea   GarageCars   GarageArea  TotalBsmtSF  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean      0.566591     0.222582     0.441781     0.333554     0.173065
# std       0.153666     0.098998     0.186829     0.150779     0.071801
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.444444     0.149868     0.250000     0.235896     0.130237
# 50%       0.555556     0.212886     0.500000     0.338505     0.162275
# 75%       0.666667     0.271807     0.500000     0.406206     0.212480
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#           1stFlrSF    SalePrice
# count  1460.000000  1460.000000
# mean      0.190139     0.202779
# std       0.088708     0.110321
# min       0.000000     0.000000
# 25%       0.125746     0.132030
# 50%       0.172786     0.177892
# 75%       0.242600     0.248715
# max       1.000000     1.000000

# %%
# import PCA from decomposition
from sklearn.decomposition import PCA

# create the PCA object to use to fit the given data
pca = PCA()

# fit the PCA with the given cleaned-up data
pca.fit(dataset_scaled)
# Out:
# PCA()

# %%
# Principal axes in feature space, representing the directions of maximum variance in the data.
print(pca.components_)
# Out:
# [[ 0.43710849  0.2303348   0.60273147  0.47429542  0.15693299  0.19382608
#    0.32472168]
#  [-0.55134394 -0.3196441   0.50672984  0.38997189 -0.18165508 -0.21619678
#   -0.32442978]
#  [-0.57889611  0.27598842 -0.13302991  0.15009985  0.38516949  0.63068894
#    0.04856635]
#  [-0.27082512  0.78266794  0.08671338 -0.08632149 -0.42325684 -0.30622013
#    0.16185463]
#  [ 0.10230868  0.07413233 -0.58838133  0.76898161 -0.10176667 -0.17844439
#   -0.06567481]
#  [ 0.28565767  0.34617293  0.08658081 -0.03198426  0.00596677  0.19964013
#   -0.86611373]
#  [-0.06649597  0.1752242   0.03216595 -0.02507416  0.77748282 -0.59367711
#   -0.07924248]]

# %%
# check the shape 
print(pca.components_.shape)
# Out:
# (7, 7)

# %%
# check the type 
print(type(pca.components_))
# Out:
# <class 'numpy.ndarray'>

# %%
# Percentage of variance explained by each of the selected components
print(pca.explained_variance_)
# Out:
# [0.08124625 0.01617458 0.00775348 0.00477149 0.00301775 0.00231828
#  0.00096669]

# %%
print(len(pca.explained_variance_))
# Out:
# 7

# %%
print(pca.singular_values_)
# Out:
# [10.88752867  4.8578499   3.36338084  2.63848474  2.09830715  1.83912224
#   1.18760079]

# %%
print(pca.mean_)
# Out:
# [0.56659056 0.22258171 0.44178082 0.3335544  0.17306538 0.19013922
#  0.20277905]

# %%
print(pca.noise_variance_)
# Out:
# 0.0

# %%
principal_components = pca.fit_transform(dataset_scaled)

print(type(principal_components))
print(principal_components.shape)

principal_components_df = pd.DataFrame(principal_components)
# Out:
# <class 'numpy.ndarray'>
# (1460, 7)

# %%
import seaborn as sns

sns.heatmap(principal_components_df.corr())

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %%
pca_low_dim = PCA(n_components = 3)

# %%
pca_low_dim.fit(dataset_scaled)
# Out:
# PCA(n_components=3)

# %%
# original components
print(dataset_scaled.shape)

# transformed components
print(pca_low_dim.transform(dataset_scaled).shape)
# Out:
# (1460, 7)
# (1460, 3)

# %%
print(pca_low_dim.explained_variance_)
# Out:
# [0.08124625 0.01617458 0.00775348]

# %%
print(pca_low_dim.explained_variance_.sum())
# Out:
# 0.10517430909009798
